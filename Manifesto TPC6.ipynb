# %% [markdown]
# # Manifesto TPC6
#
# **Autor:** Henrique Nuno Marinho Malheiro A97455
#
# **Supervisor:** José Carlos Leite Ramalho https://www.di.uminho.pt/~jcr/
#
# **Data inicio:** 2021/11/16 **Data fim:** 2021/11/19

# %% [markdown]
# ### Resumo:
#
# Para fazer o grafico do polinomio, usamos o matplotlib que vai buscar a função calcPol para calcular o polinomio, imprimindo o seu respetivo grafico
