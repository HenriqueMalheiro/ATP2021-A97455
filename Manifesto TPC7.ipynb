# %% [markdown]
# # Manifesto TPC7
#
# **Autor:** Henrique Nuno Marinho Malheiro A97455
#
# **Supervisor:** José Carlos Leite Ramalho https://www.di.uminho.pt/~jcr/
#
# **Data inicio:** 2021/11/22 **Data fim:** 2021/11/25

# %% [markdown]
# ### Resumo:
#
# EX4- Ordenamos a BD pela media dos testes com reverse verdadeiro, ou seja, da maior para a menor media. Iniciamos dois ciclos for um ate 10(nº de alunos) e outro ate 3(nº de parametros a adicionar). No fim adicionasse a media à lista aluno adicionando os varios alunos à lista BD.
#
# EX5/6- Criasse um dicionario que vai receber como chave o parametro que se esta a fazer a distribuição e o seu valor sera 1 na primeira vez que aparecer, sendo somado mais um sempre que o mesmo se repetir.
#
# EX7/8- Usamos o matplotlib que a partir da respetiva distribuição irá fazer um grafico de barras.
