# %% [markdown]
# # Manifesto TPC8
#
# **Autor:** Henrique Nuno Marinho Malheiro A97455
#
# **Supervisor:** José Carlos Leite Ramalho https://www.di.uminho.pt/~jcr/
#
# **Data inicio:** 2021/12/02 **Data fim:** 2021/12/04

# %% [markdown]
# ### Resumo:
#
# Ex6/7- Criasse um dicionario que vai receber como chave o parametro que se esta a fazer a distribuição e o seu valor sera 1 na primeira vez que aparecer, sendo somado mais um sempre que o mesmo se repetir.
#
# Ex8- Faz a distribuição para um qualquer parametro da BD, usando o mesmo metodo dos exercicios anteriores.
#
# Ex9/10- Faz o grafico de barras a partir da distribuição previamente estabelecida usando o matplotlib.
